# %% [markdown]
# # Analysis of Worthiness of Attending Universities

# %% [markdown]
# ### import utility and analysis modules

# %%
from utility import *
from analysis import *

# %% [markdown]
# ### define figure display property and save figure helper function

# %%
import matplotlib as mpl
# %matplotlib inline
mpl.rc("savefig", dpi=200)

def save(ax,name):
    fig=ax.get_figure()
    fig.savefig("plots/" + name+".png", bbox_inches='tight')

# %% [markdown]
# # 1. Tuition data and averaged cost with Room & Board Fee

# %%
save(plot_tuition_by_year(),"tuition_by_year")
save(plot_tuition_average(),"tuition_average")

# %% [markdown]
# # 2. Financial aids data and averaged cost with  aids

# %%
save(plot_financial(),"financial")
save(plot_cost_with_aid(),"cost_with_aids")

# %% [markdown]
# # 3. Salary data and averaged starting salary

# %%
save(plot_salary(),"salary_average")
save(plot_salary_range(),"salary_range")

# %% [markdown]
# # 4. Analysis on total cost with Opportunity Cost
# ### opportunity cost -> potential salary

# %%
save(plot_ug_total(),"cost_total_ug")

# %%
save(plot_grad_total(),"cost_total_grad")

# %% [markdown]
# # 5. Analysis on the time required to pay back cost

# %%
save(plot_years_to_even(),"years_to_even")
save(plot_salary_five_years(),"years_5_salary")
